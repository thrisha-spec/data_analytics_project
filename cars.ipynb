# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("cars.csv")
df
# Out:
#     Car_ID     Brand          Model  Year  Kilometers_Driven Fuel_Type  \
# 0        1    Toyota        Corolla  2018              50000    Petrol
# 1        2     Honda          Civic  2019              40000    Petrol
# 2        3      Ford        Mustang  2017              20000    Petrol
# 3        4    Maruti          Swift  2020              30000    Diesel
# 4        5   Hyundai         Sonata  2016              60000    Diesel
# ..     ...       ...            ...   ...                ...       ...
# 95      96  Mercedes        C-Class  2019              22000    Diesel
# 96      97    Toyota  Innova Crysta  2017              38000    Diesel
# 97      98      Ford       EcoSport  2018              26000    Petrol
# 98      99   Hyundai          Verna  2019              24000    Petrol
# 99     100      Tata         Altroz  2020              18000    Petrol
#
#    Transmission Owner_Type  Mileage  Engine  Power  Seats    Price
# 0        Manual      First       15    1498    108      5   800000
# 1     Automatic     Second       17    1597    140      5  1000000
# 2     Automatic      First       10    4951    395      4  2500000
# 3        Manual      Third       23    1248     74      5   600000
# 4     Automatic     Second       18    1999    194      5   850000
# ..          ...        ...      ...     ...    ...    ...      ...
# 95    Automatic      First       16    1950    191      5  2900000
# 96       Manual     Second       13    2755    171      7  1400000
# 97       Manual      Third       18    1497    121      5   750000
# 98    Automatic     Second       17    1497    113      5   850000
# 99       Manual      First       20    1199     85      5   600000
#
# [100 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['Car_ID', 'Brand', 'Model', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'Price'],
#       dtype='object')

# %%
df.head()
# Out:
#    Car_ID    Brand    Model  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0       1   Toyota  Corolla  2018              50000    Petrol       Manual
# 1       2    Honda    Civic  2019              40000    Petrol    Automatic
# 2       3     Ford  Mustang  2017              20000    Petrol    Automatic
# 3       4   Maruti    Swift  2020              30000    Diesel       Manual
# 4       5  Hyundai   Sonata  2016              60000    Diesel    Automatic
#
#   Owner_Type  Mileage  Engine  Power  Seats    Price
# 0      First       15    1498    108      5   800000
# 1     Second       17    1597    140      5  1000000
# 2      First       10    4951    395      4  2500000
# 3      Third       23    1248     74      5   600000
# 4     Second       18    1999    194      5   850000

# %%
df.tail()
# Out:
#     Car_ID     Brand          Model  Year  Kilometers_Driven Fuel_Type  \
# 95      96  Mercedes        C-Class  2019              22000    Diesel
# 96      97    Toyota  Innova Crysta  2017              38000    Diesel
# 97      98      Ford       EcoSport  2018              26000    Petrol
# 98      99   Hyundai          Verna  2019              24000    Petrol
# 99     100      Tata         Altroz  2020              18000    Petrol
#
#    Transmission Owner_Type  Mileage  Engine  Power  Seats    Price
# 95    Automatic      First       16    1950    191      5  2900000
# 96       Manual     Second       13    2755    171      7  1400000
# 97       Manual      Third       18    1497    121      5   750000
# 98    Automatic     Second       17    1497    113      5   850000
# 99       Manual      First       20    1199     85      5   600000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Car_ID             100 non-null    int64
#  1   Brand              100 non-null    object
#  2   Model              100 non-null    object
#  3   Year               100 non-null    int64
#  4   Kilometers_Driven  100 non-null    int64
#  5   Fuel_Type          100 non-null    object
#  6   Transmission       100 non-null    object
#  7   Owner_Type         100 non-null    object
#  8   Mileage            100 non-null    int64
#  9   Engine             100 non-null    int64
#  10  Power              100 non-null    int64
#  11  Seats              100 non-null    int64
#  12  Price              100 non-null    int64
# dtypes: int64(8), object(5)
# memory usage: 10.3+ KB

# %%
df.describe()
# Out:
#            Car_ID        Year  Kilometers_Driven     Mileage       Engine  \
# count  100.000000   100.00000         100.000000  100.000000   100.000000
# mean    50.500000  2018.39000       28150.000000   17.210000  1855.230000
# std     29.011492     1.17116        9121.375716    3.309902   631.311475
# min      1.000000  2016.00000       10000.000000   10.000000   999.000000
# 25%     25.750000  2017.75000       22000.000000   15.000000  1462.000000
# 50%     50.500000  2018.00000       27000.000000   17.000000  1774.000000
# 75%     75.250000  2019.00000       32000.000000   19.000000  2143.000000
# max    100.000000  2021.00000       60000.000000   25.000000  4951.000000
#
#             Power       Seats         Price
# count  100.000000  100.000000  1.000000e+02
# mean   158.130000    5.230000  1.574000e+06
# std     76.968137    0.750151  1.000265e+06
# min     68.000000    4.000000  4.500000e+05
# 25%    103.000000    5.000000  7.000000e+05
# 50%    148.000000    5.000000  1.300000e+06
# 75%    187.000000    5.000000  2.500000e+06
# max    396.000000    7.000000  4.000000e+06

# %%
df.shape
# Out:
# (100, 13)

# %%
df.isnull().sum()
# Out:
# Car_ID               0
# Brand                0
# Model                0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(8,3))
sns.countplot(x="Brand",data=df,color='red')
plt.title('cars brand')
plt.xlabel('Brand')
plt.ylabel('count of brand')
plt.show()

# %%
plt.figure(figsize=(8,3))
sns.barplot(x="Owner_Type",y='Year',data=df,color='green')
plt.title('owner type vs year')
plt.xlabel('Owner_Type')
plt.ylabel('Year')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['Year'],bins=20,kde=True,color='orange')
plt.title('cars')
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.show()

# %%
counts=df['Owner_Type'].value_counts()
counts
# Out:
# Owner_Type
# First     44
# Second    43
# Third     13
# Name: count, dtype: int64

# %%
owner_counts = df['Owner_Type'].value_counts()
plt.figure(figsize=(8,6))
plt.pie(owner_counts, labels=['First','Second','Third'],colors=['green','yellow','black'],autopct='%1.1f%%')
plt.title('cars')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Year',data=df)
plt.title('cars')
plt.xlabel('')
plt.ylabel('Year')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='Brand',y='Year',data=df)
plt.title('cars')
plt.xlabel('Brand')
plt.ylabel('Year')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Brand"]=le.fit_transform(df["Brand"])
df["Model"]=le.fit_transform(df["Model"])
df["Fuel_Type"]=le.fit_transform(df["Fuel_Type"])
df["Transmission"]=le.fit_transform(df["Transmission"])
df["Owner_Type"]=le.fit_transform(df["Owner_Type"])
df
# Out:
#     Car_ID  Brand  Model  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0        1      9     15  2018              50000          1             1
# 1        2      3     14  2019              40000          1             0
# 2        3      2     30  2017              20000          1             0
# 3        4      6     42  2020              30000          0             1
# 4        5      4     41  2016              60000          0             0
# ..     ...    ...    ...   ...                ...        ...           ...
# 95      96      7     11  2019              22000          0             0
# 96      97      9     29  2017              38000          0             1
# 97      98      2     18  2018              26000          1             1
# 98      99      4     50  2019              24000          1             0
# 99     100      8      7  2020              18000          1             1
#
#     Owner_Type  Mileage  Engine  Power  Seats    Price
# 0            0       15    1498    108      5   800000
# 1            1       17    1597    140      5  1000000
# 2            0       10    4951    395      4  2500000
# 3            2       23    1248     74      5   600000
# 4            1       18    1999    194      5   850000
# ..         ...      ...     ...    ...    ...      ...
# 95           0       16    1950    191      5  2900000
# 96           1       13    2755    171      7  1400000
# 97           2       18    1497    121      5   750000
# 98           1       17    1497    113      5   850000
# 99           0       20    1199     85      5   600000
#
# [100 rows x 13 columns]

# %%
x=df.drop(["Price"],axis=1)
y=df["Price"]
x
# Out:
#     Car_ID  Brand  Model  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0        1      9     15  2018              50000          1             1
# 1        2      3     14  2019              40000          1             0
# 2        3      2     30  2017              20000          1             0
# 3        4      6     42  2020              30000          0             1
# 4        5      4     41  2016              60000          0             0
# ..     ...    ...    ...   ...                ...        ...           ...
# 95      96      7     11  2019              22000          0             0
# 96      97      9     29  2017              38000          0             1
# 97      98      2     18  2018              26000          1             1
# 98      99      4     50  2019              24000          1             0
# 99     100      8      7  2020              18000          1             1
#
#     Owner_Type  Mileage  Engine  Power  Seats
# 0            0       15    1498    108      5
# 1            1       17    1597    140      5
# 2            0       10    4951    395      4
# 3            2       23    1248     74      5
# 4            1       18    1999    194      5
# ..         ...      ...     ...    ...    ...
# 95           0       16    1950    191      5
# 96           1       13    2755    171      7
# 97           2       18    1497    121      5
# 98           1       17    1497    113      5
# 99           0       20    1199     85      5
#
# [100 rows x 12 columns]

# %%
y
# Out:
# 0      800000
# 1     1000000
# 2     2500000
# 3      600000
# 4      850000
#        ...
# 95    2900000
# 96    1400000
# 97     750000
# 98     850000
# 99     600000
# Name: Price, Length: 100, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-1.71481604,  1.19759354, -0.79589113, ..., -0.56870447,
#         -0.65458965, -0.30814935],
#        [-1.68017329, -0.61237151, -0.85369005, ..., -0.41109805,
#         -0.23673869, -0.30814935],
#        [-1.64553055, -0.91403235,  0.07109267, ...,  4.92841654,
#          3.09301119, -1.64792914],
#        ...,
#        [ 1.64553055, -0.91403235, -0.62249437, ..., -0.57029646,
#         -0.4848377 , -0.30814935],
#        [ 1.68017329, -0.31071067,  1.22707108, ..., -0.57029646,
#         -0.58930044, -0.30814935],
#        [ 1.71481604,  0.8959327 , -1.2582825 , ..., -1.04470771,
#         -0.95492003, -0.30814935]], shape=(100, 12))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=47)
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print(y_pred)
# Out:
# [1602033.34582198  365231.70746975 2842997.32529205 2234831.60143678
#  1925344.2088942   545938.95359866 3067463.52002494  810892.34862687
#  1607587.12395304 2745170.74954996  970921.57187492 1238628.3556572
#   203740.34706631  397429.31537859 1401427.47334107  345243.67128173
#  2021922.2992578  1578311.90724363 1214786.52145171  443524.02863395]

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print(r2)
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
print(mae)
# Out:
# 0.9649248252409195
# 156962.3968146939

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=47)
model=LinearRegression()
model.fit(x_test,y_test)
y_pred=model.predict(x_test)
print(y_pred)
# Out:
# [1611235.80997482  372763.07858464 2992413.58756143 2073089.38938747
#  1879190.73487001  697571.8040175  3781272.54770255  995740.52257074
#  1672780.6877548  3281639.291728    762848.40211402 1142992.69389787
#   134728.82387917  822755.06689391 1833164.2320391   497623.79243321
#  2340203.24691074 1171887.53896297 1114798.46592801  821300.28278905]

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print(r2)
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
print(mae)
# Out:
# 0.9649248252409195
# 156962.3968146939

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
y_pred
# Out:
# array([1600000.,  500000., 2800000., 2400000., 1600000.,  650000.,
#        4000000.,  700000., 1500000., 3200000.,  700000.,  850000.,
#         450000.,  650000., 1800000.,  550000., 2500000., 1200000.,
#         850000.,  650000.])

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print(r2)
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
print(mae)
# Out:
# 0.9914124583440144
# 42500.0

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(x_test,y_test)
y_pred=dt.predict(x_test)
y_pred
# Out:
# array([1900000.,  500000., 2800000., 2400000., 1600000.,  750000.,
#        4000000.,  850000., 1500000., 3200000.,  700000., 1000000.,
#         450000.,  650000., 1800000.,  550000., 2500000., 1200000.,
#         850000.,  800000.])

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print(r2)
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
print(mae)
# Out:
# 1.0
# 0.0

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
y_pred
# Out:
# array([1614000.,  533500., 2907000., 2224000., 1790000.,  638000.,
#        3445000.,  709000., 1568000., 3224000.,  733000., 1275000.,
#         491500.,  697000., 1934500.,  551500., 2168000., 1033000.,
#         817500.,  721000.])

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print(r2)
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
print(mae)
# Out:
# 0.9614846834145091
# 141775.0

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_test,y_test)
y_pred=rf.predict(x_test)
y_pred
# Out:
# array([1596500.,  548500., 2691000., 2225000., 1796000.,  747000.,
#        3565500.,  817000., 1751000., 3251000.,  692000., 1278000.,
#         518000.,  735500., 1983500.,  587000., 2371000., 1230000.,
#         924500.,  859000.])

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print(r2)
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
print(mae)
# Out:
# 0.9701731607280184
# 127850.0

# %%
from sklearn.neighbors import KNeighborsRegressor
kn=KNeighborsRegressor()
kn.fit(x_train,y_train)
y_pred=kn.predict(x_test)
y_pred
# Out:
# array([2100000.,  600000., 3020000., 2700000., 1920000.,  980000.,
#        3020000.,  640000., 1980000., 3020000., 1130000., 1990000.,
#         620000.,  840000., 1780000.,  640000., 1640000., 1120000.,
#        1090000., 1710000.])

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print(r2)
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
print(mae)
# Out:
# 0.7702537810817739
# 360000.0

# %%
from sklearn.neighbors import KNeighborsRegressor
kn=KNeighborsRegressor()
kn.fit(x_test,y_test)
y_pred=kn.predict(x_test)
y_pred
# Out:
# array([1370000.,  630000., 2650000., 1350000., 1460000.,  850000.,
#        2820000.,  790000., 1250000., 2290000.,  570000., 1060000.,
#         640000.,  790000., 1670000.,  640000., 2400000., 1130000.,
#         990000., 1190000.])

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print(r2)
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
print(mae)
# Out:
# 0.7935503716995642
# 297000.0

# %%
from sklearn.svm import SVC
svm=SVC()
svm.fit(x_train,y_train)
y_pred=svm.predict(x_test)
y_pred
# Out:
# array([2000000,  500000, 2800000, 2700000, 1600000,  650000, 2700000,
#         850000,  850000, 2700000,  700000,  850000,  600000,  650000,
#         850000,  700000, 2500000,  650000,  700000,  850000])

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print(r2)
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
print(mae)
# Out:
# 0.8067162266085619
# 255000.0

# %%
from sklearn.svm import SVC
svm=SVC()
svm.fit(x_test,y_test)
y_pred=svm.predict(x_test)
y_pred
# Out:
# array([1900000,  500000, 2800000, 2400000, 1600000,  850000, 4000000,
#         850000, 1500000, 3200000,  700000, 1000000,  850000,  650000,
#        1800000,  850000, 2500000, 1200000,  850000,  800000])

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print(r2)
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
print(mae)
# Out:
# 0.9866700845936939
# 40000.0
